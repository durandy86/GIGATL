# %%
from matplotlib import pyplot as plt
import numpy as np
import xarray as xr
import pandas as pd
from xgcm import Grid
import dask.array as da

from scipy.signal import savgol_filter

from modes_func import *
from definition.defPrincipal import *

# %matplotlib inline

# %%
from dask.distributed import Client, LocalCluster
#
# Initialisation d'un cluster de 32 coeurs
cluster = LocalCluster(processes=False, n_workers=1, threads_per_worker=6)
client = Client(cluster)
client
# Out:
# <Client: 'inproc://134.246.212.50/21360/1' processes=1 threads=6, memory=33.67 GB>

# %%
def adjust_grid(ds):
        # relevant to regular/analytical grid for now
        #
        ds = ds.reset_coords([c for c in ds.coords if 'nav' in c])
        
        # rename redundant dimensions
        _dims = (d for d in ['x_v', 'y_u', 'x_w', 'y_w'] if d in ds.dims)
        for d in _dims:
            ds = ds.rename({d: d[0]+'_rho'})
                
        # change nav variables to coordinates        
        _coords = [d for d in [d for d in ds.data_vars.keys()] if "nav_" in d]
        ds = ds.set_coords(_coords) 
        
        # rename coordinates 
        eta_suff={}
        for c in ds.coords:
            new_c = c.replace('nav_lat','eta').replace('nav_lon','xi')
            ds = ds.rename({c:new_c})
            # reset names and units
            ds[new_c] = (ds[new_c].assign_attrs(units='m', 
                                               standard_name=new_c,
                                               long_name=new_c)
                        )
        return ds

# %%
zarr_dir = '/media/durand/Gigatl/giga_2004a2014_mean/'
#V = ds.data_vars
V = ['zeta','bvf']
datasets = []
for v in V:
    ds = xr.open_zarr(zarr_dir+'%s.zarr'%(v))
    datasets.append(ds)
ds = xr.merge(datasets)
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (s_w: 51, x_rho: 1502, x_w: 1502, y_rho: 2002, y_w: 2002)
# Coordinates:
#     nav_lat_rho  (y_rho, x_rho) float32 dask.array<chunksize=(2002, 1502), meta=np.ndarray>
#     nav_lon_rho  (y_rho, x_rho) float32 dask.array<chunksize=(2002, 1502), meta=np.ndarray>
#     nav_lat_w    (y_w, x_w) float32 dask.array<chunksize=(2002, 1502), meta=np.ndarray>
#     nav_lon_w    (y_w, x_w) float32 dask.array<chunksize=(2002, 1502), meta=np.ndarray>
#   * s_w          (s_w) float32 -1.0 -0.98 -0.96 -0.94 ... -0.06 -0.04 -0.02 0.0
# Dimensions without coordinates: x_rho, x_w, y_rho, y_w
# Data variables:
#     zeta         (y_rho, x_rho) float32 dask.array<chunksize=(2002, 1502), meta=np.ndarray>
#     bvf          (s_w, y_w, x_w) float32 dask.array<chunksize=(51, 2002, 1502), meta=np.ndarray>

# %%
# On ajoute dans le dataset les paramètres de grille qui sont dans le 1ier fichier
path="/media/durand/Gigatl/data/"
gridname = path+'GIGATL6_12h_inst_2004-01-15-2004-01-19.nc'
gd = xr.open_dataset(gridname, chunks={'s_rho': 1})
ds['hc'] = gd.hc
ds['h'] = gd.h
ds['Vtransform'] = gd.Vtransform
ds['sc_r'] = gd.sc_r
ds['sc_w'] = gd.sc_w
ds['Cs_r'] = gd.Cs_r
ds['Cs_w'] = gd.Cs_w
ds['angle'] = gd.angle
ds['mask_rho'] = gd.mask_rho

# %%
# On modifie des dimensions et des coordonnées, on crée la grille xgcm
ds = adjust_grid(ds)
L = ds.dims['x_rho']
M = ds.dims['y_rho']
N = ds.dims['s_rho']
#ds = ds.chunk({'s_rho': 1, 's_w':1, 'x_rho':1000, 'x_u':1000, 'y_rho':1000, 'y_v':1000})
#ds = ds.chunk({'s_rho': 1, 's_w':1, 'x_rho':1, 'x_u':1})
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (s_rho: 50, s_w: 51, x_rho: 1502, y_rho: 2002)
# Coordinates:
#     eta_rho     (y_rho, x_rho) float32 dask.array<chunksize=(2002, 1502), meta=np.ndarray>
#     xi_rho      (y_rho, x_rho) float32 dask.array<chunksize=(2002, 1502), meta=np.ndarray>
#     eta_w       (y_rho, x_rho) float32 dask.array<chunksize=(2002, 1502), meta=np.ndarray>
#     xi_w        (y_rho, x_rho) float32 dask.array<chunksize=(2002, 1502), meta=np.ndarray>
#   * s_w         (s_w) float32 -1.0 -0.98 -0.96 -0.94 ... -0.06 -0.04 -0.02 0.0
#   * s_rho       (s_rho) float32 -0.99 -0.97 -0.95 -0.93 ... -0.05 -0.03 -0.01
# Dimensions without coordinates: x_rho, y_rho
# Data variables:
#     zeta        (y_rho, x_rho) float32 dask.array<chunksize=(2002, 1502), meta=np.ndarray>
#     bvf         (s_w, y_rho, x_rho) float32 dask.array<chunksize=(51, 2002, 1502), meta=np.ndarray>
#     hc          float32 ...
#     h           (y_rho, x_rho) float32 dask.array<chunksize=(2002, 1502), meta=np.ndarray>
#     Vtransform  float32 ...
#     sc_r        (s_rho) float32 dask.array<chunksize=(1,), meta=np.ndarray>
#     sc_w        (s_w) float32 dask.array<chunksize=(51,), meta=np.ndarray>
#     Cs_r        (s_rho) float32 dask.array<chunksize=(1,), meta=np.ndarray>
#     Cs_w        (s_w) float32 dask.array<chunksize=(51,), meta=np.ndarray>
#     angle       (y_rho, x_rho) float32 dask.array<chunksize=(2002, 1502), meta=np.ndarray>
#     mask_rho    (y_rho, x_rho) float32 dask.array<chunksize=(2002, 1502), meta=np.ndarray>

# %%
# On crée la grille xgcm
ds = xgcm_grid(ds)
grid = ds.attrs['xgcm-Grid']

# %%
# %%time
# Compute depth at rho point
z = get_z(ds,zeta=ds['zeta'],hgrid='r').compute()
# Out:
# /home/durand/croco/relationDispersion/definition/defPrincipal.py:166: FutureWarning: This DataArray contains multi-dimensional coordinates. In the future, these coordinates will be transposed as well unless you specify transpose_coords=False.
#   z = z.transpose(*(zdim,)+_zeta.dims)
# CPU times: user 3.12 s, sys: 2.04 s, total: 5.16 s
# Wall time: 1.7 s

# %%
bvf=w2rho(ds.bvf,ds)

# %%
# %%time
#plot slice longitude
longitude = -30.
vnew= slice2(ds,bvf,z,longitude=longitude)
vnew.plot(x=[s for s in vnew.coords if s in ["eta_rho","eta_u","eta_v"]][0],
          y=[s for s in vnew.coords if "z" in s][0],
         #xlim=[-10.,10.], ylim=[-1000.,0.],
          xlim=[-10.,10.], 
          vmin=-0.5, vmax=0.5, cmap = 'RdBu_r')
# Out:
# CPU times: user 4.81 s, sys: 529 ms, total: 5.34 s
# Wall time: 5.61 s

# %%
# %%time
#plot slice latitude
latitude = 0.
vnew= slice2(ds,bvf,z, latitude=latitude)

plt.figure(figsize=(12,6), dpi=80)
vnew.plot(x=[s for s in vnew.coords if s in ["xi_rho","xi_u","xi_v"]][0],
          y=[s for s in vnew.coords if "z" in s][0],
          vmin=-0.0001, vmax=0.0001, cmap = 'RdBu_r')

ax = plt.gca()
ax.set_facecolor('darkkhaki')
# Out:
# CPU times: user 4.33 s, sys: 484 ms, total: 4.82 s
# Wall time: 5.04 s

# %%
findLatLonIndex(ds, -23.,0.)
# Out:
# (795, 871)

# %%
vnew2=vnew.isel(x_rho=871)
vnew2
# vnew2.plot(y='z')
N=np.sqrt(vnew2)**2
N=N*0+(1.96e-3)**2
# N.plot(y='z')
N.values

N2=savgol_filter(N, 49, 8)
plt.plot(N2)

# %%
## Compute vertical eigenmodes

phi,lmbd,zz = SL_chebsolve((N), (vnew2.z.values), Nmod="auto", Nz="auto", grav=9.80,sm=50, ksplin=3, zbot=None)

modes = phi[1]

eigval = np.real(lmbd)

for i in range(modes.shape[1]):
    modes[:,i]=norm_mode(modes[:,i],zz)


# modes[:,0] = np.ones(modes[:,0].shape)

# %%
plt.plot(modes[:,2],zz)
plt.grid()

# %%
eigval
# Out:
# array([5.14919027e-03, 4.16756459e-01, 8.33417443e-01, 1.25009964e+00,
#        1.66678714e+00, 2.08347676e+00, 2.50016745e+00, 2.91685874e+00,
#        3.33355041e+00, 3.75024233e+00, 4.16693443e+00, 4.58362666e+00,
#        5.00031898e+00, 5.41701138e+00, 5.83370384e+00, 6.25039634e+00,
#        6.66708888e+00, 7.08378146e+00, 7.50047405e+00, 7.91716667e+00,
#        8.33385931e+00, 8.75055197e+00, 9.16724464e+00, 9.58393732e+00,
#        1.00006300e+01, 1.04173227e+01, 1.08340154e+01, 1.12507081e+01,
#        1.16674009e+01, 1.20840936e+01, 1.25007863e+01, 1.29174791e+01,
#        1.33341718e+01, 1.37508645e+01, 1.41675573e+01, 1.45842500e+01,
#        1.50009428e+01])

# %%
-np.flipud(vnew2.z.values)
# Out:
# array([2.99705336e+00, 9.71950544e+00, 1.76024735e+01, 2.66671389e+01,
#        3.69454491e+01, 4.84803130e+01, 6.13258786e+01, 7.55478585e+01,
#        9.12239113e+01, 1.08444086e+02, 1.27311285e+02, 1.47941828e+02,
#        1.70465907e+02, 1.95028191e+02, 2.21788298e+02, 2.50921374e+02,
#        2.82618311e+02, 3.17086240e+02, 3.54548579e+02, 3.95244937e+02,
#        4.39430843e+02, 4.87376864e+02, 5.39367682e+02, 5.95700228e+02,
#        6.56681282e+02, 7.22624383e+02, 7.93845528e+02, 8.70658199e+02,
#        9.53366469e+02, 1.04225750e+03, 1.13759166e+03, 1.23959132e+03,
#        1.34842854e+03, 1.46420966e+03, 1.58695894e+03, 1.71660142e+03,
#        1.85294361e+03, 1.99565451e+03, 2.14424685e+03, 2.29806056e+03,
#        2.45624926e+03, 2.61777070e+03, 2.78138720e+03, 2.94567156e+03,
#        3.10902798e+03, 3.26972520e+03, 3.42594312e+03, 3.57583609e+03,
#        3.71760900e+03, 3.84960382e+03])

# %%
zz
# Out:
# array([-3.84960382e+03, -3.84787086e+03, -3.84267510e+03, -3.83402590e+03,
#        -3.82193885e+03, -3.80643574e+03, -3.78754449e+03, -3.76529915e+03,
#        -3.73973982e+03, -3.71091254e+03, -3.67886928e+03, -3.64366776e+03,
#        -3.60537144e+03, -3.56404931e+03, -3.51977585e+03, -3.47263084e+03,
#        -3.42269924e+03, -3.37007102e+03, -3.31484104e+03, -3.25710881e+03,
#        -3.19697837e+03, -3.13455808e+03, -3.06996044e+03, -3.00330184e+03,
#        -2.93470241e+03, -2.86428577e+03, -2.79217882e+03, -2.71851150e+03,
#        -2.64341656e+03, -2.56702933e+03, -2.48948746e+03, -2.41093070e+03,
#        -2.33150059e+03, -2.25134029e+03, -2.17059424e+03, -2.08940796e+03,
#        -2.00792775e+03, -1.92630044e+03, -1.84467313e+03, -1.76319292e+03,
#        -1.68200663e+03, -1.60126059e+03, -1.52110028e+03, -1.44167018e+03,
#        -1.36311341e+03, -1.28557154e+03, -1.20918431e+03, -1.13408937e+03,
#        -1.06042205e+03, -9.88315102e+02, -9.17898465e+02, -8.49299036e+02,
#        -7.82640437e+02, -7.18042791e+02, -6.55622506e+02, -5.95492069e+02,
#        -5.37759839e+02, -4.82529852e+02, -4.29901638e+02, -3.79970036e+02,
#        -3.32825025e+02, -2.88551565e+02, -2.47229439e+02, -2.08933113e+02,
#        -1.73731598e+02, -1.41688331e+02, -1.12861056e+02, -8.73017208e+01,
#        -6.50563857e+01, -4.61651383e+01, -3.06620217e+01, -1.85749736e+01,
#        -9.92577584e+00, -4.73001471e+00, -2.99705336e+00])

# %%
namevar='modes'
modeCDF = xr.Dataset({namevar:(['wmod','umod'],modes)})
modeCDF.to_netcdf('modes.nc')

# %%
namevar='lamba'
modeCDF = xr.Dataset({namevar:(['lambda'],eigval)})
modeCDF.to_netcdf('lambda.nc')

# %%
plt.figure(figsize=(12,6), dpi=80)
vnew2.plot(x=[s for s in vnew.coords if s in ["xi_rho","xi_u","xi_v"]][0],
          y=[s for s in vnew.coords if "z" in s][0],
          vmin=-0.0001, vmax=0.0001, cmap = 'RdBu_r')

ax = plt.gca()
ax.set_facecolor('darkkhaki')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-e8bac550688f> in <module>
#       2 vnew2.plot(x=[s for s in vnew.coords if s in ["xi_rho","xi_u","xi_v"]][0],
#       3           y=[s for s in vnew.coords if "z" in s][0],
# ----> 4           vmin=-0.0001, vmax=0.0001, cmap = 'RdBu_r')
#       5
#       6 ax = plt.gca()
#
# ~/miniconda3/envs/croco/lib/python3.7/site-packages/xarray/plot/plot.py in __call__(self, **kwargs)
#     444
#     445     def __call__(self, **kwargs):
# --> 446         return plot(self._da, **kwargs)
#     447
#     448     @functools.wraps(hist)
#
# ~/miniconda3/envs/croco/lib/python3.7/site-packages/xarray/plot/plot.py in plot(darray, row, col, col_wrap, ax, hue, rtol, subplot_kws, **kwargs)
#     198     kwargs["ax"] = ax
#     199
# --> 200     return plotfunc(darray, **kwargs)
#     201
#     202
#
# ~/miniconda3/envs/croco/lib/python3.7/site-packages/xarray/plot/plot.py in line(darray, row, col, figsize, aspect, size, ax, hue, x, y, xincrease, yincrease, xscale, yscale, xticks, yticks, xlim, ylim, add_legend, _labels, *args, **kwargs)
#     293
#     294     ax = get_axis(figsize, size, aspect, ax)
# --> 295     xplt, yplt, hueplt, xlabel, ylabel, hue_label = _infer_line_data(darray, x, y, hue)
#     296
#     297     # Remove pd.Intervals if contained in xplt.values and/or yplt.values.
#
# ~/miniconda3/envs/croco/lib/python3.7/site-packages/xarray/plot/plot.py in _infer_line_data(darray, x, y, hue)
#      42
#      43     if x is not None and y is not None:
# ---> 44         raise ValueError("You cannot specify both x and y kwargs" "for line plots.")
#      45
#      46     if ndims == 1:
#
# ValueError: You cannot specify both x and y kwargsfor line plots.

# %%
# %%time
# plot slice depth
depth=-1000.
vnew= slice(ds,bvf,z,depth=depth)
print(vnew)
vnew.plot(x=[s for s in u.coords if "xi_" in s][0],
                       y=[s for s in u.coords if "eta_" in s][0],
                       vmin=-0.5, vmax=0.5, cmap='RdBu_r')

# %%
cluster.close()
